# %% [markdown]
# # My First Jupyter Notebook
#
# ## Assignment
#
# A01 ITAI 1378 Colab and other Tools Practice Run
#
# ## Purpose
#
# This notebook was created to practice using Google Colab, Jupyter Notebook cells, basic Python code, and GitHub submission.
#
# ## What I Am Learning
#
# In this notebook, I am learning how to use text cells to explain my work and code cells to run Python commands.

# %%
print ("Hello, Computer Vision!")
# Out:
# Hello, Computer Vision!
